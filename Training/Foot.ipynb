# %%
import ultralytics
import roboflow
from roboflow import Roboflow
import shutil

# %% [markdown]
# # Training DataSet

# %%
rf = Roboflow(api_key="ivYzaTAYcDmisbrX9BJD")
project = rf.workspace("roboflow-jvuqo").project("football-players-detection-3zvbc")
version = project.version(2)
dataset = version.download("yolov8")
# Out:
# loading Roboflow workspace...
# loading Roboflow project...
# Downloading Dataset Version Zip in football-players-detection-2 to yolov8:: 100%|██████████| 116758/116758 [00:23<00:00, 4920.21it/s]
# Extracting Dataset Version Zip to football-players-detection-2 in yolov8:: 100%|██████████| 1338/1338 [00:06<00:00, 222.68it/s]

# %% [markdown]
# # Training

# %%
# !yolo task=detect mode=train model=yolov8x.pt data={dataset.location}/data.yaml epochs=100 imgsz=640
